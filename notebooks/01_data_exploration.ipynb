# %% [markdown]
# # Exploratory Data Analysis (EDA) — IMDB Sentiment Dataset
#
# **Purpose:**
# This notebook performs minimal exploratory analysis to understand the IMDB sentiment dataset used in the ML pipeline.
# All preprocessing and data splitting are handled in the DVC pipeline (`src/data_loader.py`).
#
# **Key checks:**
# - Dataset size
# - Label distribution
# - Text length distribution

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd

df = pd.read_csv("../data/raw/reviews.csv")
df.head()
# Out:
#                                                 text  label  split
# 0  I rented I AM CURIOUS-YELLOW from my video sto...      0  train
# 1  "I Am Curious: Yellow" is a risible and preten...      0  train
# 2  If only to avoid making this type of film in t...      0  train
# 3  This film was probably inspired by Godard's Ma...      0  train
# 4  Oh, brother...after hearing about this ridicul...      0  train

# %%
df.info()
df['label'].value_counts()
df['split'].value_counts()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    50000 non-null  object
#  1   label   50000 non-null  int64
#  2   split   50000 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.1+ MB
# text     0
# label    0
# split    0
# dtype: int64

# %%
df['split'].value_counts()
df['label'].value_counts()
# Out:
# label
# 0    25000
# 1    25000
# Name: count, dtype: int64

# %%
df['split'].value_counts()
# Out:
# split
# train    25000
# test     25000
# Name: count, dtype: int64

# %%
train_df = df[df['split'] == 'train']
test_df  = df[df['split'] == 'test']
